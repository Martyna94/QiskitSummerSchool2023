# %%
import math
from qiskit import  QuantumCircuit,Aer,execute
from qiskit.quantum_info import  Statevector
from qiskit.visualization import plot_bloch_multivector

# %%
import math

from qiskit import QuantumCircuit, Aer, execute
from qiskit.quantum_info import Statevector
import numpy as np
from qiskit.visualization import plot_histogram, array_to_latex
from qiskit.quantum_info.operators import Operator
import matplotlib.pyplot as plt
from math import gcd
from qiskit.circuit.library import QFT
from qiskit.visualization import plot_bloch_multivector

# %%
qc = QuantumCircuit(1)
sv_0 = Statevector(qc)
plot_bloch_multivector(sv_0)

# %%
# qc.reset(0)
qc.ry(math.pi/4,0)
qc.draw('mpl')

# %%
sv_1 = Statevector(qc)
sv_1.probabilities_dict()
plot_bloch_multivector(sv_1)

# %%
sim = Aer.get_backend('aer_simulator')
shots = 2000
count_qpe4 = execute(qc, sim, shots=shots).result().get_counts()
plot_histogram(count_qpe4, figsize=(9,5))
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[46], line 3
#       1 sim = Aer.get_backend('aer_simulator')
#       2 shots = 2000
# ----> 3 count_qpe4 = execute(qc, sim, shots=shots).result().get_counts()
#       4 plot_histogram(count_qpe4, figsize=(9,5))
#
# File ~\anaconda3\envs\QiskitSummer2023\lib\site-packages\qiskit\result\result.py:289, in Result.get_counts(self, experiment)
#     287         dict_list.append(statevector.Statevector(vec).probabilities_dict(decimals=15))
#     288     else:
# --> 289         raise QiskitError(f'No counts for experiment "{repr(key)}"')
#     291 # Return first item of dict_list if size is 1
#     292 if len(dict_list) == 1:
#
# QiskitError: 'No counts for experiment "0"'

# %%
from qiskit import transpile
simulator = Aer.get_backend('statevector_simulator')
t_qc = transpile(qc,simulator)
result = simulator.run(t_qc).result()
state_qc = result.get_statevector()
sv_qc = Statevector(state_qc)
sv_prob = sv_qc.probabilities_dict()
sv_prob['0']
#aer_sim = Aer.get_backend('aer_simulator')
# t_qc = transpile(qc,aer_sim)
#counts = aer_sim.run(t_qc).result().get_counts()
# plot_histogram(counts)
# Out:
# 0.1464466094067263
